# %%
import numpy as np
import pandas as pd
import BHVReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6f52b40c0acf> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import BHVReader
#
# ModuleNotFoundError: No module named 'BHVReader'

# %%
data = pd.read_csv('May/20190527.trd', sep="|", header=None)

# %%
data
# Out:
#                 0           1       2         3   4  5        6         7  \
# 0        50555747   BANKNIFTY  OPTIDX  20190530  PE  0  30000.0  10:08:30
# 1        52011548   BANKNIFTY  OPTIDX  20190530  PE  0  31000.0  14:29:40
# 2        87693079     HCLTECH  FUTSTK  20190530  FF  0      0.0  12:54:30
# 3        94077443    RELIANCE  OPTSTK  20190530  CE  0   1300.0  14:44:47
# 4         1321014       NIFTY  OPTIDX  20190530  CE  0  12300.0  14:30:51
# ...           ...         ...     ...       ...  .. ..      ...       ...
# 6319110  94063332         PFC  FUTSTK  20190530  FF  0      0.0  14:33:09
# 6319111  94120969         PFC  FUTSTK  20190530  FF  0      0.0  15:16:57
# 6319112  93776960  NATIONALUM  FUTSTK  20190530  FF  0      0.0  09:24:28
# 6319113  94023006      MARUTI  OPTSTK  20190530  CE  0   7000.0  13:43:21
# 6319114  87639545      GRASIM  OPTSTK  20190530  PE  0    820.0  11:36:27
#
#                    8       9
# 0          17.350000    20.0
# ...

# %%
df = pd.read_csv('20190521.bhv', sep="|", header=None)

# %%
df
# Out:
#             0           1       2         3   4   5       6        7   \
# 0     20190521   TATAPOWER  OPTSTK  20190530  CE   0    75.0     0.35
# 1     20190521     ESCORTS  OPTSTK  20190530  PE   0   540.0     7.65
# 2     20190521    JUSTDIAL  OPTSTK  20190530  PE   0   560.0     2.80
# 3     20190521        ZEEL  OPTSTK  20190530  CE   0   470.0     1.45
# 4     20190521     HCLTECH  FUTSTK  20190627  FF   0     0.0  1076.70
# ...        ...         ...     ...       ...  ..  ..     ...      ...
# 6843  20190521  TORNTPHARM  OPTSTK  20190627  CE   0  1700.0    26.75
# 6844  20190521    TATACHEM  OPTSTK  20190530  PE   0   620.0    19.40
# 6845  20190521    TATACHEM  OPTSTK  20190530  CE   0   610.0    19.25
# 6846  20190521        SAIL  OPTSTK  20190530  CE   0    48.0     4.00
# 6847  20190521   KOTAKBANK  OPTSTK  20190627  PE   0  1500.0    51.00
#
#            8           9           10          11         12        13  \
# ...
